# %% [markdown]
# Import libraries:

# %%
import pandas as pd
import numpy as np
import os 
import glob
import re
import matplotlib.pyplot as plt
import matplotlib.colors as col
import matplotlib

# %% [markdown]
# List of files to be imported. glob glob will read all the txt:

# %%
#files to read:
files = glob.glob(os.path.join(os.getcwd(),'results','*cement*72.txt')) 
#print:
[i.split("\\")[-1] for i in files]
# Out:
# ['cement0place_temp20at120fw_rem72.txt',
#  'cement0place_temp20at144fw_rem72.txt',
#  'cement0place_temp20at168fw_rem72.txt',
#  'cement0place_temp20at192fw_rem72.txt',
#  'cement0place_temp20at1fw_rem72.txt',
#  'cement0place_temp20at216fw_rem72.txt',
#  'cement0place_temp20at72fw_rem72.txt',
#  'cement0place_temp20at96fw_rem72.txt',
#  'cement0place_temp28at120fw_rem72.txt',
#  'cement0place_temp28at144fw_rem72.txt',
#  'cement0place_temp28at168fw_rem72.txt',
#  'cement0place_temp28at192fw_rem72.txt',
#  'cement0place_temp28at1fw_rem72.txt',
#  'cement0place_temp28at216fw_rem72.txt',
#  'cement0place_temp28at72fw_rem72.txt',
#  'cement0place_temp28at96fw_rem72.txt',
#  'cement0place_temp35at120fw_rem72.txt',
#  'cement0place_temp35at144fw_rem72.txt',
#  'cement0place_temp35at168fw_rem72.txt',
#  'cement0place_temp35at192fw_rem72.txt',
#  'cement0place_temp35at1fw_rem72.txt',
#  'cement0place_temp35at216fw_rem72.txt',
#  'cement0place_temp35at72fw_rem72.txt',
#  'cement0place_temp35at96fw_rem72.txt',
#  'cement1place_temp20at120fw_rem72.txt',
#  'cement1place_temp20at144fw_rem72.txt',
#  'cement1place_temp20at168fw_rem72.txt',
#  'cement1place_temp20at192fw_rem72.txt',
#  'cement1place_temp20at1fw_rem72.txt',
#  'cement1place_temp20at216fw_rem72.txt',
#  'cement1place_temp20at72fw_rem72.txt',
#  'cement1place_temp20at96fw_rem72.txt',
#  'cement1place_temp28at120fw_rem72.txt',
#  'cement1place_temp28at144fw_rem72.txt',
#  'cement1place_temp28at168fw_rem72.txt',
#  'cement1place_temp28at192fw_rem72.txt',
#  'cement1place_temp28at1fw_rem72.txt',
#  'cement1place_temp28at216fw_rem72.txt',
#  'cement1place_temp28at72fw_rem72.txt',
#  'cement1place_temp28at96fw_rem72.txt',
#  'cement1place_temp35at120fw_rem72.txt',
#  'cement1place_temp35at144fw_rem72.txt',
#  'cement1place_temp35at168fw_rem72.txt',
#  'cement1place_temp35at192fw_rem72.txt',
#  'cement1place_temp35at1fw_rem72.txt',
#  'cement1place_temp35at216fw_rem72.txt',
#  'cement1place_temp35at72fw_rem72.txt',
#  'cement1place_temp35at96fw_rem72.txt']

# %% [markdown]
# Read data:

# %%
keymap_list = []
for idx,i in enumerate(files):
    with open(i, 'r') as f:
        file_lines = f.readlines()
    keymap_list.append(pd.DataFrame([string.split('\t') for string in file_lines]))
    keymap_list[idx].loc[:,"File"] = i.split("\\")[-1]
keymap = pd.concat(keymap_list)

# %% [markdown]
# Clean data:

# %%
keymap.iloc[:,0].where(keymap.iloc[:,0].str.contains("Time Step"),inplace = True)
keymap.iloc[:,0].fillna(method='ffill',inplace = True)
keymap.dropna(axis=0, how="any",inplace = True)
keymap.iloc[:,0] = keymap.iloc[:,0].str.split(" ").apply(lambda x: (x[-1]))
keymap.iloc[0,0] = "Time"
keymap = keymap.drop(keymap.index[0]).reset_index(drop = True)
cols = ["Time [h]", "Node", "X [m]", "Y [m]", "Z [m]", "Temp [C]", "File"]
keymap.columns = cols
keymap = (pd.merge(keymap.loc[:,keymap.columns != "File"].apply(pd.to_numeric, errors='coerce'),
                  keymap.loc[:,keymap.columns == "File"], left_index = True, right_index = True)
            .dropna()
            .reset_index(drop = True))

# %%
#search for integers in a string (text naming) and 
keymap_file_ID = pd.DataFrame(
    keymap.loc[:,"File"].apply(lambda x: re.findall("[-+]?\d*\.\d+|\d+", x)).tolist(), 
    columns=['Cement ID', 'Placing Temperature [C]', '2nd pour time [h]',"Fw removed a/ 2nd pr time [h]"]
)

keymap = pd.concat([keymap, keymap_file_ID.astype(float)], axis=1)

# %% [markdown]
# Add feature, cement ID, placing temperature and 2nd pouring time

# %%
keymap["Fw removed a/ 2nd pr time [h]"].unique()
# Out:
# array([72.])

# %%
#Categorize the feature. whether is 1st or 2nd pour for the 3D module
#get the nodes between 0 and 3
keymap = keymap.loc[keymap.loc[:,"Y [m]"].between(0, 3.01),:]

#get the framework removed at 2nd
#keymap = keymap.loc[keymap.loc[:,"Fw removed a/ 2nd pr time [h]"] == 336.0,:]

#label 1st and 2nd pour taking into account time:
keymap.loc[:,"2nd pour"] = np.nan
keymap.loc[keymap.loc[:,"Time [h]"] <= keymap.loc[:,"2nd pour time [h]"],"2nd pour"] = "Before"
keymap.loc[keymap.loc[:,"Time [h]"] > keymap.loc[:,"2nd pour time [h]"],"2nd pour"] = "After"

#label 1st and 2nd pour taking into account dimensional feature:
keymap.loc[:,"Feature"] = np.nan
keymap.loc[keymap.loc[:,"Y [m]"].between(0, 1.51),"Feature"] = "1st Pour"
keymap.loc[keymap.loc[:,"Y [m]"].between(1.51, 3.01),"Feature"] = "2nd Pour"
keymap.dropna(axis=0, how='any',inplace=True)


#Categorize the feature. whether is 1st, 2nd pour or corbel for the 3D model
#keymap.loc[keymap.loc[:,"Z [m]"].between(-3.12794, -1.62795),"Feature"] = "1st Pour"
#keymap.loc[keymap.loc[:,"Z [m]"] > -1.62795,"Feature"] = "2nd Pour"
#keymap.loc[keymap.loc[:,"Z [m]"] < -3.12794,"Feature"] = "corbel"
#keymap.head()

# %%
keymap
# Out:
#          Time [h]   Node  X [m]  Y [m]  Z [m]  Temp [C]  \
# 320           0.0  321.0   0.00    0.0    0.0   15.0000
# 321           0.0  322.0   0.16    0.0    0.0   15.0000
# 322           0.0  323.0   0.32    0.0    0.0   15.0000
# 323           0.0  324.0   0.48    0.0    0.0   15.0000
# 324           0.0  325.0   0.64    0.0    0.0   15.0000
# ...           ...    ...    ...    ...    ...       ...
# 5241625    5000.0  657.0   2.56    3.0    0.0   15.0112
# 5241626    5000.0  658.0   2.72    3.0    0.0   15.0102
# 5241627    5000.0  659.0   2.88    3.0    0.0   15.0086
# 5241628    5000.0  660.0   3.04    3.0    0.0   15.0064
# 5241629    5000.0  661.0   3.20    3.0    0.0   15.0022
#
#                                          File  Cement ID  \
# 320      cement0place_temp20at120fw_rem72.txt        0.0
# 321      cement0place_temp20at120fw_rem72.txt        0.0
# 322      cement0place_temp20at120fw_rem72.txt        0.0
# 323      cement0place_temp20at120fw_rem72.txt        0.0
# 324      cement0place_temp20at120fw_rem72.txt        0.0
# ...                                       ...        ...
# 5241625   cement1place_temp35at96fw_rem72.txt        1.0
# 5241626   cement1place_temp35at96fw_rem72.txt        1.0
# 5241627   cement1place_temp35at96fw_rem72.txt        1.0
# 5241628   cement1place_temp35at96fw_rem72.txt        1.0
# 5241629   cement1place_temp35at96fw_rem72.txt        1.0
#
#          Placing Temperature [C]  2nd pour time [h]  \
# 320                         20.0              120.0
# 321                         20.0              120.0
# 322                         20.0              120.0
# 323                         20.0              120.0
# 324                         20.0              120.0
# ...                          ...                ...
# 5241625                     35.0               96.0
# 5241626                     35.0               96.0
# 5241627                     35.0               96.0
# 5241628                     35.0               96.0
# 5241629                     35.0               96.0
#
#          Fw removed a/ 2nd pr time [h] 2nd pour   Feature
# 320                               72.0   Before  1st Pour
# 321                               72.0   Before  1st Pour
# 322                               72.0   Before  1st Pour
# 323                               72.0   Before  1st Pour
# 324                               72.0   Before  1st Pour
# ...                                ...      ...       ...
# 5241625                           72.0    After  2nd Pour
# 5241626                           72.0    After  2nd Pour
# 5241627                           72.0    After  2nd Pour
# 5241628                           72.0    After  2nd Pour
# 5241629                           72.0    After  2nd Pour
#
# [2505630 rows x 13 columns]

# %%
# #Max absolute temperature for 1st pour:
# keymap_1st = keymap.loc[keymap.loc[:,"Time [hours]"]<=keymap.loc[:,"2nd pouring time [hours]"],:]
# idx1 = keymap_1st.groupby(['File'])['Temp [C]'].transform(max) == keymap_1st['Temp [C]']
# keymap_1st[idx1].drop_duplicates(subset=['Node', 'Temp [C]', "File"], keep="first")

# %%
# #Max absolute temperature for 2nd pour:
# keymap_2nd = keymap.loc[keymap.loc[:,"Time [hours]"]>keymap.loc[:,"2nd pouring time [hours]"],:]
# idx2 = keymap_2nd.groupby(['File'])['Temp [C]'].transform(max) == keymap_2nd['Temp [C]']
# keymap_2nd[idx2].drop_duplicates(subset=['Node', 'Temp [C]', "File"], keep="first")

# %% [markdown]
# Calculate maximum temperature:

# %%
#Max absolute temperature for 1st and 2nd pour:
                         
#function max_min_idx
def max_min_idx(df, max_or_min,by_columns,on_columns):
    return df.groupby(by_columns)[on_columns].transform(max_or_min) == df[on_columns]

#index for 1st and 2nd pour:
idx_max = max_min_idx(keymap, max, ['File',"Feature"], 'Temp [C]')

#max temperature dataframe
keymap_maxT = (keymap[idx_max]
               .sort_values(by=["Cement ID",
                                "Placing Temperature [C]",
                                "Fw removed a/ 2nd pr time [h]",
                                "2nd pour time [h]",
                                "Feature"
                               ]
                           )
               .reset_index(drop=True)
              )

#print
keymap_maxT.set_index("File").head(16)
# Out:
#                                       Time [h]   Node  X [m]  Y [m]  Z [m]  \
# File
# cement0place_temp20at1fw_rem72.txt    115.1950  458.0   1.44   1.20    0.0
# cement0place_temp20at1fw_rem72.txt     96.9363  507.0   1.60   1.65    0.0
# cement0place_temp20at72fw_rem72.txt   167.9360  490.0   1.44   1.50    0.0
# cement0place_temp20at72fw_rem72.txt   113.5300  553.0   1.28   2.10    0.0
# cement0place_temp20at96fw_rem72.txt   191.9360  490.0   1.44   1.50    0.0
# cement0place_temp20at96fw_rem72.txt   137.5300  553.0   1.28   2.10    0.0
# cement0place_temp20at120fw_rem72.txt   71.4967  379.0   1.60   0.45    0.0
# cement0place_temp20at120fw_rem72.txt  164.6020  553.0   1.28   2.10    0.0
# cement0place_temp20at144fw_rem72.txt   71.4967  379.0   1.60   0.45    0.0
# cement0place_temp20at144fw_rem72.txt  188.6020  553.0   1.28   2.10    0.0
# cement0place_temp20at168fw_rem72.txt   71.4967  379.0   1.60   0.45    0.0
# cement0place_temp20at168fw_rem72.txt  215.8270  553.0   1.28   2.10    0.0
# cement0place_temp20at192fw_rem72.txt   71.4967  379.0   1.60   0.45    0.0
# cement0place_temp20at192fw_rem72.txt  243.2130  553.0   1.28   2.10    0.0
# cement0place_temp20at216fw_rem72.txt   71.4967  379.0   1.60   0.45    0.0
# cement0place_temp20at216fw_rem72.txt  267.2130  553.0   1.28   2.10    0.0
#
#                                       Temp [C]  Cement ID  \
# File
# cement0place_temp20at1fw_rem72.txt     76.8589        0.0
# cement0place_temp20at1fw_rem72.txt     75.5664        0.0
# cement0place_temp20at72fw_rem72.txt    73.9396        0.0
# cement0place_temp20at72fw_rem72.txt    80.5053        0.0
# cement0place_temp20at96fw_rem72.txt    71.2518        0.0
# cement0place_temp20at96fw_rem72.txt    79.6593        0.0
# cement0place_temp20at120fw_rem72.txt   71.0848        0.0
# cement0place_temp20at120fw_rem72.txt   76.5108        0.0
# cement0place_temp20at144fw_rem72.txt   71.0848        0.0
# cement0place_temp20at144fw_rem72.txt   76.6576        0.0
# cement0place_temp20at168fw_rem72.txt   71.0848        0.0
# cement0place_temp20at168fw_rem72.txt   74.3617        0.0
# cement0place_temp20at192fw_rem72.txt   71.0848        0.0
# cement0place_temp20at192fw_rem72.txt   72.4045        0.0
# cement0place_temp20at216fw_rem72.txt   71.0848        0.0
# cement0place_temp20at216fw_rem72.txt   70.7221        0.0
#
#                                       Placing Temperature [C]  \
# File
# cement0place_temp20at1fw_rem72.txt                       20.0
# cement0place_temp20at1fw_rem72.txt                       20.0
# cement0place_temp20at72fw_rem72.txt                      20.0
# cement0place_temp20at72fw_rem72.txt                      20.0
# cement0place_temp20at96fw_rem72.txt                      20.0
# cement0place_temp20at96fw_rem72.txt                      20.0
# cement0place_temp20at120fw_rem72.txt                     20.0
# cement0place_temp20at120fw_rem72.txt                     20.0
# cement0place_temp20at144fw_rem72.txt                     20.0
# cement0place_temp20at144fw_rem72.txt                     20.0
# cement0place_temp20at168fw_rem72.txt                     20.0
# cement0place_temp20at168fw_rem72.txt                     20.0
# cement0place_temp20at192fw_rem72.txt                     20.0
# cement0place_temp20at192fw_rem72.txt                     20.0
# cement0place_temp20at216fw_rem72.txt                     20.0
# cement0place_temp20at216fw_rem72.txt                     20.0
#
#                                       2nd pour time [h]  \
# File
# cement0place_temp20at1fw_rem72.txt                  1.0
# cement0place_temp20at1fw_rem72.txt                  1.0
# cement0place_temp20at72fw_rem72.txt                72.0
# cement0place_temp20at72fw_rem72.txt                72.0
# cement0place_temp20at96fw_rem72.txt                96.0
# cement0place_temp20at96fw_rem72.txt                96.0
# cement0place_temp20at120fw_rem72.txt              120.0
# cement0place_temp20at120fw_rem72.txt              120.0
# cement0place_temp20at144fw_rem72.txt              144.0
# cement0place_temp20at144fw_rem72.txt              144.0
# cement0place_temp20at168fw_rem72.txt              168.0
# cement0place_temp20at168fw_rem72.txt              168.0
# cement0place_temp20at192fw_rem72.txt              192.0
# cement0place_temp20at192fw_rem72.txt              192.0
# cement0place_temp20at216fw_rem72.txt              216.0
# cement0place_temp20at216fw_rem72.txt              216.0
#
#                                       Fw removed a/ 2nd pr time [h] 2nd pour  \
# File
# cement0place_temp20at1fw_rem72.txt                             72.0    After
# cement0place_temp20at1fw_rem72.txt                             72.0    After
# cement0place_temp20at72fw_rem72.txt                            72.0    After
# cement0place_temp20at72fw_rem72.txt                            72.0    After
# cement0place_temp20at96fw_rem72.txt                            72.0    After
# cement0place_temp20at96fw_rem72.txt                            72.0    After
# cement0place_temp20at120fw_rem72.txt                           72.0   Before
# cement0place_temp20at120fw_rem72.txt                           72.0    After
# cement0place_temp20at144fw_rem72.txt                           72.0   Before
# cement0place_temp20at144fw_rem72.txt                           72.0    After
# cement0place_temp20at168fw_rem72.txt                           72.0   Before
# cement0place_temp20at168fw_rem72.txt                           72.0    After
# cement0place_temp20at192fw_rem72.txt                           72.0   Before
# cement0place_temp20at192fw_rem72.txt                           72.0    After
# cement0place_temp20at216fw_rem72.txt                           72.0   Before
# cement0place_temp20at216fw_rem72.txt                           72.0    After
#
#                                        Feature
# File
# cement0place_temp20at1fw_rem72.txt    1st Pour
# cement0place_temp20at1fw_rem72.txt    2nd Pour
# cement0place_temp20at72fw_rem72.txt   1st Pour
# cement0place_temp20at72fw_rem72.txt   2nd Pour
# cement0place_temp20at96fw_rem72.txt   1st Pour
# cement0place_temp20at96fw_rem72.txt   2nd Pour
# cement0place_temp20at120fw_rem72.txt  1st Pour
# cement0place_temp20at120fw_rem72.txt  2nd Pour
# cement0place_temp20at144fw_rem72.txt  1st Pour
# cement0place_temp20at144fw_rem72.txt  2nd Pour
# cement0place_temp20at168fw_rem72.txt  1st Pour
# cement0place_temp20at168fw_rem72.txt  2nd Pour
# cement0place_temp20at192fw_rem72.txt  1st Pour
# cement0place_temp20at192fw_rem72.txt  2nd Pour
# cement0place_temp20at216fw_rem72.txt  1st Pour
# cement0place_temp20at216fw_rem72.txt  2nd Pour

# %% [markdown]
# Calculate the minimum temperature for the maximum temperature nodes:

# %%
#Min absolute temperature for 1st and 2nd pour taking into account Max Temperature nodes:

#calculate the mask for Nodes and & File -- a cycle had to be used. For each node, only the correspondent file is valid:
df_min = []
for index, row in keymap_maxT.iterrows():
    mask_1 = keymap.loc[:,"Node"] == row.Node
    mask_2 = keymap.loc[:,"File"] == row.File
    df_min.append(keymap.loc[mask_1 & mask_2,:])
df_mins = pd.concat(df_min)

#for each file and node, calculate at what time reaches the min temperature idx. 
idx_min = max_min_idx(df_mins, min,['File',"Node"], 'Temp [C]')

#min temperature dataframe based on max temperature dataframe
keymap_minT = df_mins[idx_min].sort_values(by=["Cement ID","Placing Temperature [C]","2nd pour time [h]","Feature"]).reset_index(drop=True)

#print
keymap_minT.set_index("File").head(16)
# Out:
#                                       Time [h]   Node  X [m]  Y [m]  Z [m]  \
# File
# cement0place_temp20at1fw_rem72.txt      5000.0  458.0   1.44   1.20    0.0
# cement0place_temp20at1fw_rem72.txt      5000.0  507.0   1.60   1.65    0.0
# cement0place_temp20at72fw_rem72.txt     5000.0  490.0   1.44   1.50    0.0
# cement0place_temp20at72fw_rem72.txt     5000.0  553.0   1.28   2.10    0.0
# cement0place_temp20at96fw_rem72.txt     5000.0  490.0   1.44   1.50    0.0
# cement0place_temp20at96fw_rem72.txt     5000.0  553.0   1.28   2.10    0.0
# cement0place_temp20at120fw_rem72.txt    5000.0  379.0   1.60   0.45    0.0
# cement0place_temp20at120fw_rem72.txt    5000.0  553.0   1.28   2.10    0.0
# cement0place_temp20at144fw_rem72.txt    5000.0  379.0   1.60   0.45    0.0
# cement0place_temp20at144fw_rem72.txt    5000.0  553.0   1.28   2.10    0.0
# cement0place_temp20at168fw_rem72.txt    5000.0  379.0   1.60   0.45    0.0
# cement0place_temp20at168fw_rem72.txt    5000.0  553.0   1.28   2.10    0.0
# cement0place_temp20at192fw_rem72.txt    5000.0  379.0   1.60   0.45    0.0
# cement0place_temp20at192fw_rem72.txt    5000.0  553.0   1.28   2.10    0.0
# cement0place_temp20at216fw_rem72.txt    5000.0  379.0   1.60   0.45    0.0
# cement0place_temp20at216fw_rem72.txt    5000.0  553.0   1.28   2.10    0.0
#
#                                       Temp [C]  Cement ID  \
# File
# cement0place_temp20at1fw_rem72.txt     15.0797        0.0
# cement0place_temp20at1fw_rem72.txt     15.0781        0.0
# cement0place_temp20at72fw_rem72.txt    15.0813        0.0
# cement0place_temp20at72fw_rem72.txt    15.0695        0.0
# cement0place_temp20at96fw_rem72.txt    15.0876        0.0
# cement0place_temp20at96fw_rem72.txt    15.0743        0.0
# cement0place_temp20at120fw_rem72.txt   15.0873        0.0
# cement0place_temp20at120fw_rem72.txt   15.0824        0.0
# cement0place_temp20at144fw_rem72.txt   15.0906        0.0
# cement0place_temp20at144fw_rem72.txt   15.0852        0.0
# cement0place_temp20at168fw_rem72.txt   15.0962        0.0
# cement0place_temp20at168fw_rem72.txt   15.0919        0.0
# cement0place_temp20at192fw_rem72.txt   15.1012        0.0
# cement0place_temp20at192fw_rem72.txt   15.0981        0.0
# cement0place_temp20at216fw_rem72.txt   15.1058        0.0
# cement0place_temp20at216fw_rem72.txt   15.1037        0.0
#
#                                       Placing Temperature [C]  \
# File
# cement0place_temp20at1fw_rem72.txt                       20.0
# cement0place_temp20at1fw_rem72.txt                       20.0
# cement0place_temp20at72fw_rem72.txt                      20.0
# cement0place_temp20at72fw_rem72.txt                      20.0
# cement0place_temp20at96fw_rem72.txt                      20.0
# cement0place_temp20at96fw_rem72.txt                      20.0
# cement0place_temp20at120fw_rem72.txt                     20.0
# cement0place_temp20at120fw_rem72.txt                     20.0
# cement0place_temp20at144fw_rem72.txt                     20.0
# cement0place_temp20at144fw_rem72.txt                     20.0
# cement0place_temp20at168fw_rem72.txt                     20.0
# cement0place_temp20at168fw_rem72.txt                     20.0
# cement0place_temp20at192fw_rem72.txt                     20.0
# cement0place_temp20at192fw_rem72.txt                     20.0
# cement0place_temp20at216fw_rem72.txt                     20.0
# cement0place_temp20at216fw_rem72.txt                     20.0
#
#                                       2nd pour time [h]  \
# File
# cement0place_temp20at1fw_rem72.txt                  1.0
# cement0place_temp20at1fw_rem72.txt                  1.0
# cement0place_temp20at72fw_rem72.txt                72.0
# cement0place_temp20at72fw_rem72.txt                72.0
# cement0place_temp20at96fw_rem72.txt                96.0
# cement0place_temp20at96fw_rem72.txt                96.0
# cement0place_temp20at120fw_rem72.txt              120.0
# cement0place_temp20at120fw_rem72.txt              120.0
# cement0place_temp20at144fw_rem72.txt              144.0
# cement0place_temp20at144fw_rem72.txt              144.0
# cement0place_temp20at168fw_rem72.txt              168.0
# cement0place_temp20at168fw_rem72.txt              168.0
# cement0place_temp20at192fw_rem72.txt              192.0
# cement0place_temp20at192fw_rem72.txt              192.0
# cement0place_temp20at216fw_rem72.txt              216.0
# cement0place_temp20at216fw_rem72.txt              216.0
#
#                                       Fw removed a/ 2nd pr time [h] 2nd pour  \
# File
# cement0place_temp20at1fw_rem72.txt                             72.0    After
# cement0place_temp20at1fw_rem72.txt                             72.0    After
# cement0place_temp20at72fw_rem72.txt                            72.0    After
# cement0place_temp20at72fw_rem72.txt                            72.0    After
# cement0place_temp20at96fw_rem72.txt                            72.0    After
# cement0place_temp20at96fw_rem72.txt                            72.0    After
# cement0place_temp20at120fw_rem72.txt                           72.0    After
# cement0place_temp20at120fw_rem72.txt                           72.0    After
# cement0place_temp20at144fw_rem72.txt                           72.0    After
# cement0place_temp20at144fw_rem72.txt                           72.0    After
# cement0place_temp20at168fw_rem72.txt                           72.0    After
# cement0place_temp20at168fw_rem72.txt                           72.0    After
# cement0place_temp20at192fw_rem72.txt                           72.0    After
# cement0place_temp20at192fw_rem72.txt                           72.0    After
# cement0place_temp20at216fw_rem72.txt                           72.0    After
# cement0place_temp20at216fw_rem72.txt                           72.0    After
#
#                                        Feature
# File
# cement0place_temp20at1fw_rem72.txt    1st Pour
# cement0place_temp20at1fw_rem72.txt    2nd Pour
# cement0place_temp20at72fw_rem72.txt   1st Pour
# cement0place_temp20at72fw_rem72.txt   2nd Pour
# cement0place_temp20at96fw_rem72.txt   1st Pour
# cement0place_temp20at96fw_rem72.txt   2nd Pour
# cement0place_temp20at120fw_rem72.txt  1st Pour
# cement0place_temp20at120fw_rem72.txt  2nd Pour
# cement0place_temp20at144fw_rem72.txt  1st Pour
# cement0place_temp20at144fw_rem72.txt  2nd Pour
# cement0place_temp20at168fw_rem72.txt  1st Pour
# cement0place_temp20at168fw_rem72.txt  2nd Pour
# cement0place_temp20at192fw_rem72.txt  1st Pour
# cement0place_temp20at192fw_rem72.txt  2nd Pour
# cement0place_temp20at216fw_rem72.txt  1st Pour
# cement0place_temp20at216fw_rem72.txt  2nd Pour

# %% [markdown]
# Calculate the maximum drop of temperature (T1) for the maximum temperature nodes:

# %%
from functools import reduce
# Merge Min and Max data, and T1 calculation. (4 dataframes, thus why using reduce)
dfs = [ keymap_maxT.loc[:,["Node","X [m]", "Y [m]", "Feature","File","2nd pour"]],
        keymap_maxT.loc[:,["Time [h]","Temp [C]"]].add_suffix(" max"),
        keymap_minT.loc[:,["Time [h]","Temp [C]"]].add_suffix(" min"),
        keymap_maxT.loc[:,"Temp [C]"].subtract(keymap_minT.loc[:,"Temp [C]"])
      ]
T1 = reduce(lambda left,right: pd.merge(left,right,left_index=True, right_index = True), dfs)

#print
T1.set_index("File").rename(columns={"Temp [C]": "T1 [C]"}).head(16)
# Out:
#                                        Node  X [m]  Y [m]   Feature 2nd pour  \
# File
# cement0place_temp20at1fw_rem72.txt    458.0   1.44   1.20  1st Pour    After
# cement0place_temp20at1fw_rem72.txt    507.0   1.60   1.65  2nd Pour    After
# cement0place_temp20at72fw_rem72.txt   490.0   1.44   1.50  1st Pour    After
# cement0place_temp20at72fw_rem72.txt   553.0   1.28   2.10  2nd Pour    After
# cement0place_temp20at96fw_rem72.txt   490.0   1.44   1.50  1st Pour    After
# cement0place_temp20at96fw_rem72.txt   553.0   1.28   2.10  2nd Pour    After
# cement0place_temp20at120fw_rem72.txt  379.0   1.60   0.45  1st Pour   Before
# cement0place_temp20at120fw_rem72.txt  553.0   1.28   2.10  2nd Pour    After
# cement0place_temp20at144fw_rem72.txt  379.0   1.60   0.45  1st Pour   Before
# cement0place_temp20at144fw_rem72.txt  553.0   1.28   2.10  2nd Pour    After
# cement0place_temp20at168fw_rem72.txt  379.0   1.60   0.45  1st Pour   Before
# cement0place_temp20at168fw_rem72.txt  553.0   1.28   2.10  2nd Pour    After
# cement0place_temp20at192fw_rem72.txt  379.0   1.60   0.45  1st Pour   Before
# cement0place_temp20at192fw_rem72.txt  553.0   1.28   2.10  2nd Pour    After
# cement0place_temp20at216fw_rem72.txt  379.0   1.60   0.45  1st Pour   Before
# cement0place_temp20at216fw_rem72.txt  553.0   1.28   2.10  2nd Pour    After
#
#                                       Time [h] max  Temp [C] max  \
# File
# cement0place_temp20at1fw_rem72.txt        115.1950       76.8589
# cement0place_temp20at1fw_rem72.txt         96.9363       75.5664
# cement0place_temp20at72fw_rem72.txt       167.9360       73.9396
# cement0place_temp20at72fw_rem72.txt       113.5300       80.5053
# cement0place_temp20at96fw_rem72.txt       191.9360       71.2518
# cement0place_temp20at96fw_rem72.txt       137.5300       79.6593
# cement0place_temp20at120fw_rem72.txt       71.4967       71.0848
# cement0place_temp20at120fw_rem72.txt      164.6020       76.5108
# cement0place_temp20at144fw_rem72.txt       71.4967       71.0848
# cement0place_temp20at144fw_rem72.txt      188.6020       76.6576
# cement0place_temp20at168fw_rem72.txt       71.4967       71.0848
# cement0place_temp20at168fw_rem72.txt      215.8270       74.3617
# cement0place_temp20at192fw_rem72.txt       71.4967       71.0848
# cement0place_temp20at192fw_rem72.txt      243.2130       72.4045
# cement0place_temp20at216fw_rem72.txt       71.4967       71.0848
# cement0place_temp20at216fw_rem72.txt      267.2130       70.7221
#
#                                       Time [h] min  Temp [C] min   T1 [C]
# File
# cement0place_temp20at1fw_rem72.txt          5000.0       15.0797  61.7792
# cement0place_temp20at1fw_rem72.txt          5000.0       15.0781  60.4883
# cement0place_temp20at72fw_rem72.txt         5000.0       15.0813  58.8583
# cement0place_temp20at72fw_rem72.txt         5000.0       15.0695  65.4358
# cement0place_temp20at96fw_rem72.txt         5000.0       15.0876  56.1642
# cement0place_temp20at96fw_rem72.txt         5000.0       15.0743  64.5850
# cement0place_temp20at120fw_rem72.txt        5000.0       15.0873  55.9975
# cement0place_temp20at120fw_rem72.txt        5000.0       15.0824  61.4284
# cement0place_temp20at144fw_rem72.txt        5000.0       15.0906  55.9942
# cement0place_temp20at144fw_rem72.txt        5000.0       15.0852  61.5724
# cement0place_temp20at168fw_rem72.txt        5000.0       15.0962  55.9886
# cement0place_temp20at168fw_rem72.txt        5000.0       15.0919  59.2698
# cement0place_temp20at192fw_rem72.txt        5000.0       15.1012  55.9836
# cement0place_temp20at192fw_rem72.txt        5000.0       15.0981  57.3064
# cement0place_temp20at216fw_rem72.txt        5000.0       15.1058  55.9790
# cement0place_temp20at216fw_rem72.txt        5000.0       15.1037  55.6184

# %% [markdown]
# Calculate the maximum Delta T:

# %%
#Calculate 1st pour and 2nd pour Delta T (DT)

# #index for 1st and 2nd pour max and min temperatures for each file and time step:
idx_Dmax = max_min_idx(keymap, max, ['File','Time [h]',"2nd pour"], 'Temp [C]')
idx_Dmin = max_min_idx(keymap, min, ['File','Time [h]',"2nd pour"], 'Temp [C]')
#idx_Dmax = max_min_idx(keymap, max, ['File','Time [h]'], 'Temp [C]')
#idx_Dmin = max_min_idx(keymap, min, ['File','Time [h]'], 'Temp [C]')

#Dmax and Dmin represent the max and min temperatures for 1st and 2nd pour
Dmax = keymap[idx_Dmax].drop_duplicates(subset=['Time [h]',"Temp [C]",'File']).drop(columns=["Z [m]"])
Dmin = keymap[idx_Dmin].drop_duplicates(subset=['Time [h]',"Temp [C]",'File']).drop(columns=["Z [m]"])

#DT represents the differencial of temperature 
on_to = ['Time [h]',"2nd pour","File","Placing Temperature [C]","2nd pour time [h]","Cement ID","Fw removed a/ 2nd pr time [h]"]
DT =  (pd.merge(Dmax, Dmin, on = on_to, how = "outer")
         .sort_values(by=["Cement ID","Placing Temperature [C]","2nd pour time [h]"])
      )     

#Get DT -- x stands for maximum. y stands for min
DT["DT [C]"] = DT["Temp [C]_x"]-DT["Temp [C]_y"]

#DTmax
idx_DT_max = max_min_idx(DT, max, ['File',"2nd pour"],"DT [C]")
DT_max = (DT[idx_DT_max]
              .drop_duplicates(subset=["DT [C]", "File"])
              .sort_values(by=["Cement ID","Placing Temperature [C]","2nd pour time [h]"])     
         )

#print
DT_max.drop(["Cement ID","Placing Temperature [C]","2nd pour time [h]"], axis=1).set_index("File").head(16)
# Out:
#                                       Time [h]  Node_x  X [m]_x  Y [m]_x  \
# File
# cement0place_temp20at1fw_rem72.txt      0.0000   342.0     0.00     0.15
# cement0place_temp20at1fw_rem72.txt    121.9000   458.0     1.44     1.20
# cement0place_temp20at72fw_rem72.txt    69.8079   379.0     1.60     0.45
# cement0place_temp20at72fw_rem72.txt   147.3990   538.0     1.28     1.95
# cement0place_temp20at96fw_rem72.txt    75.5715   379.0     1.60     0.45
# cement0place_temp20at96fw_rem72.txt   143.8270   553.0     1.28     2.10
# cement0place_temp20at120fw_rem72.txt   75.5715   379.0     1.60     0.45
# cement0place_temp20at120fw_rem72.txt  171.2130   553.0     1.28     2.10
# cement0place_temp20at144fw_rem72.txt   75.5715   379.0     1.60     0.45
# cement0place_temp20at144fw_rem72.txt  195.2130   553.0     1.28     2.10
# cement0place_temp20at168fw_rem72.txt   75.5715   379.0     1.60     0.45
# cement0place_temp20at168fw_rem72.txt  219.2130   553.0     1.28     2.10
# cement0place_temp20at192fw_rem72.txt   75.5715   379.0     1.60     0.45
# cement0place_temp20at192fw_rem72.txt  267.3990   553.0     1.28     2.10
# cement0place_temp20at216fw_rem72.txt   75.5715   379.0     1.60     0.45
# cement0place_temp20at216fw_rem72.txt  291.3990   553.0     1.28     2.10
#
#                                       Temp [C]_x  \
# File
# cement0place_temp20at1fw_rem72.txt       20.0000
# cement0place_temp20at1fw_rem72.txt       76.8174
# cement0place_temp20at72fw_rem72.txt      71.0880
# cement0place_temp20at72fw_rem72.txt      78.2860
# cement0place_temp20at96fw_rem72.txt      71.0435
# cement0place_temp20at96fw_rem72.txt      79.5316
# cement0place_temp20at120fw_rem72.txt     71.0435
# cement0place_temp20at120fw_rem72.txt     76.3910
# cement0place_temp20at144fw_rem72.txt     71.0435
# cement0place_temp20at144fw_rem72.txt     76.4573
# cement0place_temp20at168fw_rem72.txt     71.0435
# cement0place_temp20at168fw_rem72.txt     74.2903
# cement0place_temp20at192fw_rem72.txt     71.0435
# cement0place_temp20at192fw_rem72.txt     70.4813
# cement0place_temp20at216fw_rem72.txt     71.0435
# cement0place_temp20at216fw_rem72.txt     69.1066
#
#                                       Fw removed a/ 2nd pr time [h] 2nd pour  \
# File
# cement0place_temp20at1fw_rem72.txt                             72.0   Before
# cement0place_temp20at1fw_rem72.txt                             72.0    After
# cement0place_temp20at72fw_rem72.txt                            72.0   Before
# cement0place_temp20at72fw_rem72.txt                            72.0    After
# cement0place_temp20at96fw_rem72.txt                            72.0   Before
# cement0place_temp20at96fw_rem72.txt                            72.0    After
# cement0place_temp20at120fw_rem72.txt                           72.0   Before
# cement0place_temp20at120fw_rem72.txt                           72.0    After
# cement0place_temp20at144fw_rem72.txt                           72.0   Before
# cement0place_temp20at144fw_rem72.txt                           72.0    After
# cement0place_temp20at168fw_rem72.txt                           72.0   Before
# cement0place_temp20at168fw_rem72.txt                           72.0    After
# cement0place_temp20at192fw_rem72.txt                           72.0   Before
# cement0place_temp20at192fw_rem72.txt                           72.0    After
# cement0place_temp20at216fw_rem72.txt                           72.0   Before
# cement0place_temp20at216fw_rem72.txt                           72.0    After
#
#                                      Feature_x  Node_y  X [m]_y  Y [m]_y  \
# File
# cement0place_temp20at1fw_rem72.txt    1st Pour   321.0      0.0      0.0
# cement0place_temp20at1fw_rem72.txt    1st Pour   661.0      3.2      3.0
# cement0place_temp20at72fw_rem72.txt   1st Pour   501.0      3.2      1.5
# cement0place_temp20at72fw_rem72.txt   2nd Pour   661.0      3.2      3.0
# cement0place_temp20at96fw_rem72.txt   1st Pour   501.0      3.2      1.5
# cement0place_temp20at96fw_rem72.txt   2nd Pour   661.0      3.2      3.0
# cement0place_temp20at120fw_rem72.txt  1st Pour   501.0      3.2      1.5
# cement0place_temp20at120fw_rem72.txt  2nd Pour   661.0      3.2      3.0
# cement0place_temp20at144fw_rem72.txt  1st Pour   501.0      3.2      1.5
# cement0place_temp20at144fw_rem72.txt  2nd Pour   661.0      3.2      3.0
# cement0place_temp20at168fw_rem72.txt  1st Pour   501.0      3.2      1.5
# cement0place_temp20at168fw_rem72.txt  2nd Pour   661.0      3.2      3.0
# cement0place_temp20at192fw_rem72.txt  1st Pour   501.0      3.2      1.5
# cement0place_temp20at192fw_rem72.txt  2nd Pour   661.0      3.2      3.0
# cement0place_temp20at216fw_rem72.txt  1st Pour   501.0      3.2      1.5
# cement0place_temp20at216fw_rem72.txt  2nd Pour   661.0      3.2      3.0
#
#                                       Temp [C]_y Feature_y   DT [C]
# File
# cement0place_temp20at1fw_rem72.txt       15.0000  1st Pour   5.0000
# cement0place_temp20at1fw_rem72.txt       15.6048  2nd Pour  61.2126
# cement0place_temp20at72fw_rem72.txt      17.8836  1st Pour  53.2044
# cement0place_temp20at72fw_rem72.txt      16.5807  2nd Pour  61.7053
# cement0place_temp20at96fw_rem72.txt      17.7142  1st Pour  53.3293
# cement0place_temp20at96fw_rem72.txt      19.0231  2nd Pour  60.5085
# cement0place_temp20at120fw_rem72.txt     17.7142  1st Pour  53.3293
# cement0place_temp20at120fw_rem72.txt     18.7563  2nd Pour  57.6347
# cement0place_temp20at144fw_rem72.txt     17.7142  1st Pour  53.3293
# cement0place_temp20at144fw_rem72.txt     18.7603  2nd Pour  57.6970
# cement0place_temp20at168fw_rem72.txt     17.7142  1st Pour  53.3293
# cement0place_temp20at168fw_rem72.txt     18.6987  2nd Pour  55.5916
# cement0place_temp20at192fw_rem72.txt     17.7142  1st Pour  53.3293
# cement0place_temp20at192fw_rem72.txt     16.5358  2nd Pour  53.9455
# cement0place_temp20at216fw_rem72.txt     17.7142  1st Pour  53.3293
# cement0place_temp20at216fw_rem72.txt     16.5261  2nd Pour  52.5805

# %%
DT_max.loc[DT_max.loc[:,"File"] == "cement0place_temp28at216fw_rem216.txt",:]
# Out:
# Empty DataFrame
# Columns: [Time [h], Node_x, X [m]_x, Y [m]_x, Temp [C]_x, File, Cement ID, Placing Temperature [C], 2nd pour time [h], Fw removed a/ 2nd pr time [h], 2nd pour, Feature_x, Node_y, X [m]_y, Y [m]_y, Temp [C]_y, Feature_y, DT [C]]
# Index: []

# %%
#max temperature for keymap dataframe taking into account File and Time:
idx_max = max_min_idx(keymap, max, ['File',"Time [h]"], 'Temp [C]')
dfs = (keymap[idx_max].sort_values(by=["Cement ID","Placing Temperature [C]","2nd pour time [h]","Feature"]))

# %%
#dataframe to be plot:

#Pot max temperatures
no_cement_id = len(dfs.loc[:,"Cement ID"].unique())
no_plac_temp = len(dfs.loc[:,"Placing Temperature [C]"].unique())
no_files = len(dfs.loc[:,"File"].unique())
no_fw_rem = len(dfs.loc[:,"Fw removed a/ 2nd pr time [h]"].unique())

#Set figure and axes
fig, ax = plt.subplots(no_cement_id,no_plac_temp)
fig.set_figwidth(20)
fig.set_figheight(20)
#fig.suptitle("Tmax")

#Tmax thereshold:
thereshold = 70

#set colour map
no_files_per_analysis = int(no_files / (no_cement_id * no_plac_temp * no_fw_rem)) # number of diff files per analysis
cmap = matplotlib.cm.get_cmap('Greys') # define the colour map
colormap = [cmap(i/float(no_files_per_analysis)) for i in range(0,no_files_per_analysis,1)]  # transform cmap into a list
colormap[0] = (1, 0, 0, 1.0) # set first colour as red
colormap[-1] = (0, 0, 1, 1.0) # set last colour as blue

#set linestyles (-- for 1st pour feature. - for 2nd pour feature)
linestyles = ['-', '--']
markers = ["^", "H"]

#Cycle through CEMENT ID and PLACING TEMPERATURE
for ic, cement in enumerate(dfs.loc[:,"Cement ID"].unique().tolist()):
    for ip, place in enumerate(dfs.loc[:,"Placing Temperature [C]"].unique().tolist()):
        
        #masks:
        mask1 = dfs.loc[:,"Cement ID"] == cement
        mask2 = dfs.loc[:,"Placing Temperature [C]"] == place
        
        #titles:
        ax[ic,ip].set(title = "Cement {} w/ placing temperature of {}".format(int(cement),place))
        ax[ic,ip].set(xlabel = "Time [h]", ylabel = "Temperature [C]")
        ax[ic,ip].axhline(y=thereshold,label = "Tmax")
        
#Cycle through column 2nd pour time [h] - At what time the 2nd pour is done
        for sec_time_i,sec_time in enumerate(dfs.loc[:,"2nd pour time [h]"].unique().tolist()):
            
            #masks:
            mask3 = dfs.loc[:,"2nd pour time [h]"] == sec_time
            
            for fw_i, fw_rem in enumerate(dfs.loc[:,"Fw removed a/ 2nd pr time [h]"].unique().tolist()):
                
                #masks:
                mask4 = dfs.loc[:, "Fw removed a/ 2nd pr time [h]"] == fw_rem
            
                #plot:
                (dfs.loc[(mask1 & mask2 & mask3 & mask4),:]
                    .drop_duplicates(subset=["Time [h]", "Temp [C]", "File"])
                    .sort_values(by=["Time [h]"])
                    .plot(kind = 'line',
                          x = "Time [h]", 
                          y = "Temp [C]",
                          ax = ax[ic,ip],
                          label = "2nd pour at {} hours w/ {}".format(sec_time, fw_rem),
                          color = colormap[sec_time_i],
                          linestyle = linestyles[fw_i],
                          #marker = markers[fw_i]
                         )                                         
                )
                

# Defining custom 'xlim' and 'ylim' values.
custom_xlim = (0, 2000)
custom_ylim = (15, 100)

# Setting the values for all axes.
plt.setp(ax, xlim=custom_xlim, ylim=custom_ylim);

# %%
# #Dataframe 
# df=[]
# for index, row in keymap_maxT.iterrows():
#     mask_1 = keymap.loc[:,"Node"] == row.loc["Node"]
#     mask_2 = keymap.loc[:,"File"] == row.loc["File"]
#     df1 = keymap.loc[mask_1 & mask_2,:]
#     df1.loc[:,"before_after"] = row.loc["2nd pour"]
#     df.append(df1)
# dfs = pd.concat(df)

# #Pot max temperatures
# no_cement_id = len(dfs.loc[:,"Cement ID"].unique())
# no_plac_temp = len(dfs.loc[:,"Placing Temperature [C]"].unique())
# no_files = len(dfs.loc[:,"File"].unique())

# #Set figure and axes
# fig, ax = plt.subplots(no_cement_id,no_plac_temp)
# fig.set_figwidth(20)
# fig.set_figheight(20)
# #fig.suptitle("Tmax")

# #Tmax thereshold:
# thereshold = 70

# #set colour map
# no_files_per_analysis = no_files / (no_cement_id * no_plac_temp) # number of diff files per analysis
# cmap = matplotlib.cm.get_cmap('Greys') # define the colour map
# colormap = [cmap(i/float(no_files_per_analysis)) for i in range(0,no_files_per_analysis,1)]  # transform cmap into a list
# colormap[0] = (1, 0, 0, 1.0) # set first colour as red
# colormap[-1] = (0, 0, 1, 1.0) # set last colour as blue

# #set linestyles (-- for 1st pour feature. - for 2nd pour feature)
# linestyles = ['--', '-']

# #Cycle through CEMENT ID and PLACING TEMPERATURE
# for ic, cement in enumerate(dfs.loc[:,"Cement ID"].unique().tolist()):
#     for ip, place in enumerate(dfs.loc[:,"Placing Temperature [C]"].unique().tolist()):
#         mask1 = dfs.loc[:,"Cement ID"] == cement
#         mask2 = dfs.loc[:,"Placing Temperature [C]"] == place
#         ax[ic,ip].set(title = "Cement {} w/ placing temperature of {}".format(int(cement),place))
#         ax[ic,ip].set(xlabel = "Time [h]", ylabel = "Temperature [C]")
#         ax[ic,ip].axhline(y=thereshold,label = "Tmax")
        
# #Cycle through column 2nd pour time [h] - At what time the 2nd pour is done
#         for sec_time_i,sec_time in enumerate(dfs.loc[:,"2nd pour time [h]"].unique().tolist()):
#             mask3 = dfs.loc[:,"2nd pour time [h]"] == sec_time
#             plot_df = dfs.loc[(mask1 & mask2 & mask3),:]
            
# #Cycle through each node in plot df
#             for node_i,node in enumerate(plot_df.loc[:,"Node"].unique().tolist()):
#                 mask4 = plot_df.loc[:,"Node"] == node
# #                before_after = plot_df.loc[mask4,"before_after"].unique()[0]
#                 feature = plot_df.loc[mask4,"Feature"].unique()[0]
#                 plot_df.loc[mask4,:].plot(kind = 'line', 
#                                           x = "Time [h]", 
#                                           y = "Temp [C]",
#                                           ax = ax[ic,ip],
#                                           label = "{1} 2nd pour at {0} hours in {2} feat.".format(sec_time, before_after,feature),
#                                           color = colormap[sec_time_i],
#                                           linestyle = linestyles[node_i])
#                 #print int(sec_time_i)/7.0                     

# # Defining custom 'xlim' and 'ylim' values.
# custom_xlim = (0, 2000)
# custom_ylim = (15, 95)

# # Setting the values for all axes.
# plt.setp(ax, xlim=custom_xlim, ylim=custom_ylim)

# %%
#Dataframe to be plotted:
df_to_plot = DT

#Set figure and axes
fig_DT, ax_DT = plt.subplots(no_cement_id,no_plac_temp)
fig_DT.set_figwidth(20)
fig_DT.set_figheight(20)

#Cycle through CEMENT ID and PLACING TEMPERATURE
for ic, cement in enumerate(df_to_plot.loc[:,"Cement ID"].unique().tolist()):
    for ip, place in enumerate(df_to_plot.loc[:,"Placing Temperature [C]"].unique().tolist()):
        
        #mask:
        mask1 = df_to_plot.loc[:,"Cement ID"] == cement
        mask2 = df_to_plot.loc[:,"Placing Temperature [C]"] == place
        
        #titles:
        ax_DT[ic,ip].set(title = "Cement {} w/ placing temperature of {}".format(int(cement),place))
        ax_DT[ic,ip].set(xlabel = "Time [h]", ylabel = "Temperature [C]")
        ax_DT[ic,ip].axhline(y=20,label = "DTmax")
        
#Cycle through column 2nd pour time [h] - At what time the 2nd pour is done
        for sec_time_i,sec_time in enumerate(df_to_plot.loc[:,"2nd pour time [h]"].unique().tolist()):
            
            #mask:
            mask3 = df_to_plot.loc[:,"2nd pour time [h]"] == sec_time
            
            for fw_i, fw_rem in enumerate(df_to_plot.loc[:,"Fw removed a/ 2nd pr time [h]"].unique().tolist()):
                
                #masks:
                mask4 = df_to_plot.loc[:, "Fw removed a/ 2nd pr time [h]"] == fw_rem
                
                #masked dataframe:
                plot_df = df_to_plot.loc[(mask1 & mask2 & mask3 & mask4),:]

                #plot:
                plot_df.plot(kind = 'line', 
                             x = "Time [h]", 
                             y = "DT [C]",
                             ax = ax_DT[ic,ip],
                             label = "2nd pour at {} hours w/ {}".format(sec_time,fw_rem),
                             color = colormap[sec_time_i],
                             linestyle = linestyles[fw_i]
                             #marker = markers[fw_i]
                            )

# Defining custom 'xlim' and 'ylim' values.
custom_xlim = (0, 2000)
custom_ylim = (0, 80)

# Setting the values for all axes.
plt.setp(ax_DT, xlim=custom_xlim, ylim=custom_ylim);
